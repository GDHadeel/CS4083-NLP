# %% [markdown]
# # Assignment 1: 10 minutes to pandas
#
# ## Names: Hadeel Balhmar, Deema Hamidah, Shumokh Naji, Sahar Albardawil

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Object creation

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range("20130101", periods=6)
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2013-01-01  1.376800  1.122674 -0.530543  1.836353
# 2013-01-02  1.312002 -0.018947  0.629130 -0.311868
# 2013-01-03  1.317707 -1.200107  0.078708  0.759506
# 2013-01-04  0.467706 -0.212310  0.120863 -0.473349
# 2013-01-05 -1.305733 -0.646929 -1.475415  0.595769
# 2013-01-06 -0.657485  0.470321  0.394430  0.363371

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    }
)
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A          float64
# B    datetime64[s]
# C          float32
# D            int32
# E         category
# F           object
# dtype: object

# %% [markdown]
# ### Viewing data

# %%
df.head()
# Out:
#                    A         B         C         D
# 2013-01-01  1.376800  1.122674 -0.530543  1.836353
# 2013-01-02  1.312002 -0.018947  0.629130 -0.311868
# 2013-01-03  1.317707 -1.200107  0.078708  0.759506
# 2013-01-04  0.467706 -0.212310  0.120863 -0.473349
# 2013-01-05 -1.305733 -0.646929 -1.475415  0.595769

# %%
df.tail(3)
# Out:
#                    A         B         C         D
# 2013-01-04  0.467706 -0.212310  0.120863 -0.473349
# 2013-01-05 -1.305733 -0.646929 -1.475415  0.595769
# 2013-01-06 -0.657485  0.470321  0.394430  0.363371

# %%
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.to_numpy()
# Out:
# array([[ 1.37680004,  1.1226736 , -0.53054346,  1.83635255],
#        [ 1.31200153, -0.01894701,  0.6291305 , -0.31186775],
#        [ 1.31770736, -1.2001072 ,  0.0787082 ,  0.75950622],
#        [ 0.4677056 , -0.21230954,  0.12086348, -0.47334945],
#        [-1.30573313, -0.64692875, -1.47541512,  0.59576868],
#        [-0.65748489,  0.47032114,  0.39442951,  0.36337057]])

# %%
df2.dtypes
# Out:
# A          float64
# B    datetime64[s]
# C          float32
# D            int32
# E         category
# F           object
# dtype: object

# %%
df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo']],
#       dtype=object)

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.418499 -0.080883 -0.130471  0.461630
# std    1.153985  0.818114  0.765294  0.834113
# min   -1.305733 -1.200107 -1.475415 -0.473349
# 25%   -0.376187 -0.538274 -0.378231 -0.143058
# 50%    0.889854 -0.115628  0.099786  0.479570
# 75%    1.316281  0.348004  0.326038  0.718572
# max    1.376800  1.122674  0.629130  1.836353

# %%
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A    1.376800    1.312002    1.317707    0.467706   -1.305733   -0.657485
# B    1.122674   -0.018947   -1.200107   -0.212310   -0.646929    0.470321
# C   -0.530543    0.629130    0.078708    0.120863   -1.475415    0.394430
# D    1.836353   -0.311868    0.759506   -0.473349    0.595769    0.363371

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2013-01-01  1.836353 -0.530543  1.122674  1.376800
# 2013-01-02 -0.311868  0.629130 -0.018947  1.312002
# 2013-01-03  0.759506  0.078708 -1.200107  1.317707
# 2013-01-04 -0.473349  0.120863 -0.212310  0.467706
# 2013-01-05  0.595769 -1.475415 -0.646929 -1.305733
# 2013-01-06  0.363371  0.394430  0.470321 -0.657485

# %%
df.sort_values(by="B")
# Out:
#                    A         B         C         D
# 2013-01-03  1.317707 -1.200107  0.078708  0.759506
# 2013-01-05 -1.305733 -0.646929 -1.475415  0.595769
# 2013-01-04  0.467706 -0.212310  0.120863 -0.473349
# 2013-01-02  1.312002 -0.018947  0.629130 -0.311868
# 2013-01-06 -0.657485  0.470321  0.394430  0.363371
# 2013-01-01  1.376800  1.122674 -0.530543  1.836353

# %% [markdown]
# ### Selection

# %% [markdown]
# ### Getitem ([ ])

# %%
df["A"]
# Out:
# 2013-01-01    1.376800
# 2013-01-02    1.312002
# 2013-01-03    1.317707
# 2013-01-04    0.467706
# 2013-01-05   -1.305733
# 2013-01-06   -0.657485
# Freq: D, Name: A, dtype: float64

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2013-01-01  1.376800  1.122674 -0.530543  1.836353
# 2013-01-02  1.312002 -0.018947  0.629130 -0.311868
# 2013-01-03  1.317707 -1.200107  0.078708  0.759506

# %%
df["20130102":"20130104"]
# Out:
#                    A         B         C         D
# 2013-01-02  1.312002 -0.018947  0.629130 -0.311868
# 2013-01-03  1.317707 -1.200107  0.078708  0.759506
# 2013-01-04  0.467706 -0.212310  0.120863 -0.473349

# %% [markdown]
# ### Selection by label

# %%
df.loc[dates[0]]
# Out:
# A    1.376800
# B    1.122674
# C   -0.530543
# D    1.836353
# Name: 2013-01-01 00:00:00, dtype: float64

# %%
df.loc[:, ["A", "B"]]
# Out:
#                    A         B
# 2013-01-01  1.376800  1.122674
# 2013-01-02  1.312002 -0.018947
# 2013-01-03  1.317707 -1.200107
# 2013-01-04  0.467706 -0.212310
# 2013-01-05 -1.305733 -0.646929
# 2013-01-06 -0.657485  0.470321

# %%
df.loc["20130102":"20130104", ["A", "B"]]
# Out:
#                    A         B
# 2013-01-02  1.312002 -0.018947
# 2013-01-03  1.317707 -1.200107
# 2013-01-04  0.467706 -0.212310

# %%
df.loc[dates[0], "A"]
# Out:
# 1.37680003595545

# %%
df.at[dates[0], "A"]
# Out:
# 1.37680003595545

# %% [markdown]
# ### Selection by position

# %%
df.iloc[3]
# Out:
# A    0.467706
# B   -0.212310
# C    0.120863
# D   -0.473349
# Name: 2013-01-04 00:00:00, dtype: float64

# %%
df.iloc[3:5, 0:2]
# Out:
#                    A         B
# 2013-01-04  0.467706 -0.212310
# 2013-01-05 -1.305733 -0.646929

# %%
df.iloc[[1, 2, 4], [0, 2]]
# Out:
#                    A         C
# 2013-01-02  1.312002  0.629130
# 2013-01-03  1.317707  0.078708
# 2013-01-05 -1.305733 -1.475415

# %%
df.iloc[1:3, :]
# Out:
#                    A         B         C         D
# 2013-01-02  1.312002 -0.018947  0.629130 -0.311868
# 2013-01-03  1.317707 -1.200107  0.078708  0.759506

# %%
df.iloc[:, 1:3]
# Out:
#                    B         C
# 2013-01-01  1.122674 -0.530543
# 2013-01-02 -0.018947  0.629130
# 2013-01-03 -1.200107  0.078708
# 2013-01-04 -0.212310  0.120863
# 2013-01-05 -0.646929 -1.475415
# 2013-01-06  0.470321  0.394430

# %%
df.iloc[1, 1]
# Out:
# -0.01894701106225032

# %%
df.iat[1, 1]
# Out:
# -0.01894701106225032

# %% [markdown]
# ### Boolean indexing

# %%
df[df["A"] > 0]
# Out:
#                    A         B         C         D
# 2013-01-01  1.376800  1.122674 -0.530543  1.836353
# 2013-01-02  1.312002 -0.018947  0.629130 -0.311868
# 2013-01-03  1.317707 -1.200107  0.078708  0.759506
# 2013-01-04  0.467706 -0.212310  0.120863 -0.473349

# %%
df[df > 0]
# Out:
#                    A         B         C         D
# 2013-01-01  1.376800  1.122674       NaN  1.836353
# 2013-01-02  1.312002       NaN  0.629130       NaN
# 2013-01-03  1.317707       NaN  0.078708  0.759506
# 2013-01-04  0.467706       NaN  0.120863       NaN
# 2013-01-05       NaN       NaN       NaN  0.595769
# 2013-01-06       NaN  0.470321  0.394430  0.363371

# %%
df2 = df.copy()
df2["E"] = ["one", "one", "two", "three", "four", "three"]

df2
# Out:
#                    A         B         C         D      E
# 2013-01-01  1.376800  1.122674 -0.530543  1.836353    one
# 2013-01-02  1.312002 -0.018947  0.629130 -0.311868    one
# 2013-01-03  1.317707 -1.200107  0.078708  0.759506    two
# 2013-01-04  0.467706 -0.212310  0.120863 -0.473349  three
# 2013-01-05 -1.305733 -0.646929 -1.475415  0.595769   four
# 2013-01-06 -0.657485  0.470321  0.394430  0.363371  three

# %%
df2[df2["E"].isin(["two", "four"])]
# Out:
#                    A         B         C         D     E
# 2013-01-03  1.317707 -1.200107  0.078708  0.759506   two
# 2013-01-05 -1.305733 -0.646929 -1.475415  0.595769  four

# %% [markdown]
# ### Setting

# %%
s1 = pd.Series([1, 2, 3, 4, 5, 6], index=pd.date_range("20130102", periods=6))
s1
# Out:
# 2013-01-02    1
# 2013-01-03    2
# 2013-01-04    3
# 2013-01-05    4
# 2013-01-06    5
# 2013-01-07    6
# Freq: D, dtype: int64

# %%
df["F"] = s1

df.at[dates[0], "A"] = 0

df.iat[0, 1] = 0

df.loc[:, "D"] = np.array([5] * len(df))

df
# Out:
#                    A         B         C    D    F
# 2013-01-01  0.000000  0.000000 -0.530543  5.0  NaN
# 2013-01-02  1.312002 -0.018947  0.629130  5.0  1.0
# 2013-01-03  1.317707 -1.200107  0.078708  5.0  2.0
# 2013-01-04  0.467706 -0.212310  0.120863  5.0  3.0
# 2013-01-05 -1.305733 -0.646929 -1.475415  5.0  4.0
# 2013-01-06 -0.657485  0.470321  0.394430  5.0  5.0

# %%
df2 = df.copy()

df2[df2 > 0] = -df2

df2
# Out:
#                    A         B         C    D    F
# 2013-01-01  0.000000  0.000000 -0.530543 -5.0  NaN
# 2013-01-02 -1.312002 -0.018947 -0.629130 -5.0 -1.0
# 2013-01-03 -1.317707 -1.200107 -0.078708 -5.0 -2.0
# 2013-01-04 -0.467706 -0.212310 -0.120863 -5.0 -3.0
# 2013-01-05 -1.305733 -0.646929 -1.475415 -5.0 -4.0
# 2013-01-06 -0.657485 -0.470321 -0.394430 -5.0 -5.0

# %% [markdown]
# ### Missing data

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ["E"])

df1.loc[dates[0] : dates[1], "E"] = 1

df1
# Out:
#                    A         B         C    D    F    E
# 2013-01-01  0.000000  0.000000 -0.530543  5.0  NaN  1.0
# 2013-01-02  1.312002 -0.018947  0.629130  5.0  1.0  1.0
# 2013-01-03  1.317707 -1.200107  0.078708  5.0  2.0  NaN
# 2013-01-04  0.467706 -0.212310  0.120863  5.0  3.0  NaN

# %%
df1.dropna(how="any")
# Out:
#                    A         B        C    D    F    E
# 2013-01-02  1.312002 -0.018947  0.62913  5.0  1.0  1.0

# %%
df1.fillna(value=5)
# Out:
#                    A         B         C    D    F    E
# 2013-01-01  0.000000  0.000000 -0.530543  5.0  5.0  1.0
# 2013-01-02  1.312002 -0.018947  0.629130  5.0  1.0  1.0
# 2013-01-03  1.317707 -1.200107  0.078708  5.0  2.0  5.0
# 2013-01-04  0.467706 -0.212310  0.120863  5.0  3.0  5.0

# %%
pd.isna(df1)
# Out:
#                 A      B      C      D      F      E
# 2013-01-01  False  False  False  False   True  False
# 2013-01-02  False  False  False  False  False  False
# 2013-01-03  False  False  False  False  False   True
# 2013-01-04  False  False  False  False  False   True

# %% [markdown]
# ### Operations

# %% [markdown]
# ### Stats

# %%
df.mean()
# Out:
# A    0.189033
# B   -0.267995
# C   -0.130471
# D    5.000000
# F    3.000000
# dtype: float64

# %%
df.mean(axis=1)
# Out:
# 2013-01-01    1.117364
# 2013-01-02    1.584437
# 2013-01-03    1.439262
# 2013-01-04    1.675252
# 2013-01-05    1.114385
# 2013-01-06    2.041453
# Freq: D, dtype: float64

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8], index=dates).shift(2)
s
# Out:
# 2013-01-01    NaN
# 2013-01-02    NaN
# 2013-01-03    1.0
# 2013-01-04    3.0
# 2013-01-05    5.0
# 2013-01-06    NaN
# Freq: D, dtype: float64

# %%
df.sub(s, axis="index")
# Out:
#                    A         B         C    D    F
# 2013-01-01       NaN       NaN       NaN  NaN  NaN
# 2013-01-02       NaN       NaN       NaN  NaN  NaN
# 2013-01-03  0.317707 -2.200107 -0.921292  4.0  1.0
# 2013-01-04 -2.532294 -3.212310 -2.879137  2.0  0.0
# 2013-01-05 -6.305733 -5.646929 -6.475415  0.0 -1.0
# 2013-01-06       NaN       NaN       NaN  NaN  NaN

# %% [markdown]
# ### User defined functions

# %%
df.agg(lambda x: np.mean(x) * 5.6)
# Out:
# A     1.058583
# B    -1.500773
# C    -0.730638
# D    28.000000
# F    16.800000
# dtype: float64

# %%
df.transform(lambda x: x * 101.2)
# Out:
#                      A           B           C      D      F
# 2013-01-01    0.000000    0.000000  -53.690998  506.0    NaN
# 2013-01-02  132.774554   -1.917438   63.668006  506.0  101.2
# 2013-01-03  133.351985 -121.450849    7.965270  506.0  202.4
# 2013-01-04   47.331807  -21.485726   12.231384  506.0  303.6
# 2013-01-05 -132.140193  -65.469190 -149.312010  506.0  404.8
# 2013-01-06  -66.537471   47.596499   39.916266  506.0  506.0

# %% [markdown]
# ### Value Counts

# %%
s = pd.Series(np.random.randint(0, 7, size=10))
s
# Out:
# 0    4
# 1    3
# 2    0
# 3    4
# 4    6
# 5    6
# 6    4
# 7    5
# 8    2
# 9    0
# dtype: int64

# %%
s.value_counts()
# Out:
# 4    3
# 0    2
# 6    2
# 3    1
# 5    1
# 2    1
# Name: count, dtype: int64

# %% [markdown]
# ### String Methods

# %%
s = pd.Series(["A", "B", "C", "Aaba", "Baca", np.nan, "CABA", "dog", "cat"])
s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %% [markdown]
# ### Merge

# %% [markdown]
# ### Concat

# %%
df = pd.DataFrame(np.random.randn(10, 4))
df
# Out:
#           0         1         2         3
# 0 -2.088337  2.559359  1.375695 -0.025977
# 1  0.085896 -0.064230  0.413888 -2.097219
# 2 -0.058194 -1.915016  0.025735 -0.414211
# 3  0.354788  1.567546  0.589465  1.134590
# 4  0.942371 -0.197764 -2.359691 -0.156510
# 5 -0.711445 -0.807580 -0.344062  0.605156
# 6 -0.459284 -0.385426  1.306850 -0.110790
# 7 -0.536494  0.444455  0.255570 -0.104792
# 8 -0.186717 -0.708216 -1.219224  1.229934
# 9  0.312029 -0.966660  0.861688  1.505578

# %%
pieces = [df[:3], df[3:7], df[7:]]
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0 -2.088337  2.559359  1.375695 -0.025977
# 1  0.085896 -0.064230  0.413888 -2.097219
# 2 -0.058194 -1.915016  0.025735 -0.414211
# 3  0.354788  1.567546  0.589465  1.134590
# 4  0.942371 -0.197764 -2.359691 -0.156510
# 5 -0.711445 -0.807580 -0.344062  0.605156
# 6 -0.459284 -0.385426  1.306850 -0.110790
# 7 -0.536494  0.444455  0.255570 -0.104792
# 8 -0.186717 -0.708216 -1.219224  1.229934
# 9  0.312029 -0.966660  0.861688  1.505578

# %% [markdown]
# ### Join

# %%
left = pd.DataFrame({"key": ["foo", "foo"], "lval": [1, 2]})

# %%
right = pd.DataFrame({"key": ["foo", "foo"], "rval": [4, 5]})

# %%
left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
pd.merge(left, right, on="key")
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %%
left = pd.DataFrame({"key": ["foo", "bar"], "lval": [1, 2]})
right = pd.DataFrame({"key": ["foo", "bar"], "rval": [4, 5]})

# %%
left
# Out:
#    key  lval
# 0  foo     1
# 1  bar     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  bar     5

# %%
pd.merge(left, right, on="key")
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  bar     2     5

# %% [markdown]
# ### Grouping

# %%
df = pd.DataFrame(
    {
        "A": ["foo", "bar", "foo", "bar", "foo", "bar", "foo", "foo"],
        "B": ["one", "one", "two", "three", "two", "two", "one", "three"],
        "C": np.random.randn(8),
        "D": np.random.randn(8),
    }
)

df
# Out:
#      A      B         C         D
# 0  foo    one -1.102476  0.367148
# 1  bar    one -0.130739 -1.509465
# 2  foo    two  1.675160  1.931079
# 3  bar  three  0.303818  0.711445
# 4  foo    two  0.003820  0.517876
# 5  bar    two -0.790648  0.574388
# 6  foo    one -0.765027 -0.027203
# 7  foo  three -0.671637  0.833715

# %%
df.groupby("A")[["C", "D"]].sum()
# Out:
#             C         D
# A
# bar -0.617569 -0.223631
# foo -0.860161  3.622615

# %%
df.groupby(["A", "B"]).sum()
# Out:
#                   C         D
# A   B
# bar one   -0.130739 -1.509465
#     three  0.303818  0.711445
#     two   -0.790648  0.574388
# foo one   -1.867504  0.339945
#     three -0.671637  0.833715
#     two    1.678980  2.448954

# %% [markdown]
# ### Reshaping

# %% [markdown]
# ### Stack

# %%
arrays = [
   ["bar", "bar", "baz", "baz", "foo", "foo", "qux", "qux"],
   ["one", "two", "one", "two", "one", "two", "one", "two"],
]


index = pd.MultiIndex.from_arrays(arrays, names=["first", "second"])

df = pd.DataFrame(np.random.randn(8, 2), index=index, columns=["A", "B"])

df2 = df[:4]

df2
# Out:
#                      A         B
# first second
# bar   one    -0.324090 -0.431106
#       two    -0.290341 -1.963053
# baz   one     0.176219  1.776051
#       two     1.116215 -1.531307

# %%
stacked = df2.stack(future_stack=True)

stacked
# Out:
# first  second
# bar    one     A   -0.324090
#                B   -0.431106
#        two     A   -0.290341
#                B   -1.963053
# baz    one     A    0.176219
#                B    1.776051
#        two     A    1.116215
#                B   -1.531307
# dtype: float64

# %%
stacked.unstack()
# Out:
#                      A         B
# first second
# bar   one    -0.324090 -0.431106
#       two    -0.290341 -1.963053
# baz   one     0.176219  1.776051
#       two     1.116215 -1.531307

# %%
stacked.unstack(1)
# Out:
# second        one       two
# first
# bar   A -0.324090 -0.290341
#       B -0.431106 -1.963053
# baz   A  0.176219  1.116215
#       B  1.776051 -1.531307

# %%
stacked.unstack(0)
# Out:
# first          bar       baz
# second
# one    A -0.324090  0.176219
#        B -0.431106  1.776051
# two    A -0.290341  1.116215
#        B -1.963053 -1.531307

# %% [markdown]
# ### Pivot tables

# %%
df = pd.DataFrame(
    {
        "A": ["one", "one", "two", "three"] * 3,
        "B": ["A", "B", "C"] * 4,
        "C": ["foo", "foo", "foo", "bar", "bar", "bar"] * 2,
        "D": np.random.randn(12),
        "E": np.random.randn(12),
    }
)

df
# Out:
#         A  B    C         D         E
# 0     one  A  foo -0.128461 -1.277307
# 1     one  B  foo  1.444863 -0.618434
# 2     two  C  foo  0.450660  0.681258
# 3   three  A  bar -1.071747  0.416554
# 4     one  B  bar  0.500972 -1.466631
# 5     one  C  bar  0.320715  1.285664
# 6     two  A  foo -1.095798  1.535730
# 7   three  B  foo -0.282549  1.436526
# 8     one  C  foo -1.774531  1.818202
# 9     one  A  bar  0.775460 -0.781034
# 10    two  B  bar -2.013372 -0.212189
# 11  three  C  bar -0.654890 -1.672135

# %%
pd.pivot_table(df, values="D", index=["A", "B"], columns=["C"])
# Out:
# C             bar       foo
# A     B
# one   A  0.775460 -0.128461
#       B  0.500972  1.444863
#       C  0.320715 -1.774531
# three A -1.071747       NaN
#       B       NaN -0.282549
#       C -0.654890       NaN
# two   A       NaN -1.095798
#       B -2.013372       NaN
#       C       NaN  0.450660

# %% [markdown]
# ### Time series

# %%
rng = pd.date_range("1/1/2012", periods=100, freq="s")

ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)

ts.resample("5Min").sum()
# Out:
# 2012-01-01    25538
# Freq: 5T, dtype: int64

# %%
rng = pd.date_range("3/6/2012 00:00", periods=5, freq="D")

ts = pd.Series(np.random.randn(len(rng)), rng)

ts
# Out:
# 2012-03-06   -0.414664
# 2012-03-07   -0.236544
# 2012-03-08    0.695665
# 2012-03-09    1.247303
# 2012-03-10   -0.059697
# Freq: D, dtype: float64

# %%
ts_utc = ts.tz_localize("UTC")

ts_utc
# Out:
# 2012-03-06 00:00:00+00:00   -0.414664
# 2012-03-07 00:00:00+00:00   -0.236544
# 2012-03-08 00:00:00+00:00    0.695665
# 2012-03-09 00:00:00+00:00    1.247303
# 2012-03-10 00:00:00+00:00   -0.059697
# Freq: D, dtype: float64

# %%
ts_utc.tz_convert("US/Eastern")
# Out:
# 2012-03-05 19:00:00-05:00   -0.414664
# 2012-03-06 19:00:00-05:00   -0.236544
# 2012-03-07 19:00:00-05:00    0.695665
# 2012-03-08 19:00:00-05:00    1.247303
# 2012-03-09 19:00:00-05:00   -0.059697
# Freq: D, dtype: float64

# %%
rng
# Out:
# DatetimeIndex(['2012-03-06', '2012-03-07', '2012-03-08', '2012-03-09',
#                '2012-03-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
rng + pd.offsets.BusinessDay(5)
# Out:
# DatetimeIndex(['2012-03-13', '2012-03-14', '2012-03-15', '2012-03-16',
#                '2012-03-16'],
#               dtype='datetime64[ns]', freq=None)

# %% [markdown]
# ### Categoricals

# %%
df = pd.DataFrame(
    {"id": [1, 2, 3, 4, 5, 6], "raw_grade": ["a", "b", "b", "a", "a", "e"]}
)

# %%
df["grade"] = df["raw_grade"].astype("category")

df["grade"]
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): ['a', 'b', 'e']

# %%
new_categories = ["very good", "good", "very bad"]

df["grade"] = df["grade"].cat.rename_categories(new_categories)

# %%
df["grade"] = df["grade"].cat.set_categories(
    ["very bad", "bad", "medium", "good", "very good"]
)

df["grade"]
# Out:
# 0    very good
# 1         good
# 2         good
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (5, object): ['very bad', 'bad', 'medium', 'good', 'very good']

# %%
df.sort_values(by="grade")
# Out:
#    id raw_grade      grade
# 5   6         e   very bad
# 1   2         b       good
# 2   3         b       good
# 0   1         a  very good
# 3   4         a  very good
# 4   5         a  very good

# %%
df.groupby("grade", observed=False).size()
# Out:
# grade
# very bad     1
# bad          0
# medium       0
# good         2
# very good    3
# dtype: int64

# %% [markdown]
# ### Plotting

# %%
import matplotlib.pyplot as plt

plt.close("all")

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2000", periods=1000))

ts = ts.cumsum()

ts.plot();

# %%
df = pd.DataFrame(
    np.random.randn(1000, 4), index=ts.index, columns=["A", "B", "C", "D"]
)

df = df.cumsum()

plt.figure();

df.plot();

plt.legend(loc='best');

# %% [markdown]
# ### Importing and exporting data

# %% [markdown]
# ### CSV

# %%
df = pd.DataFrame(np.random.randint(0, 5, (10, 5)))

df.to_csv("foo.csv")

# %%
pd.read_csv("foo.csv")
# Out:
#    Unnamed: 0  0  1  2  3  4
# 0           0  1  1  0  2  4
# 1           1  3  3  0  1  2
# 2           2  2  0  3  3  1
# 3           3  1  3  3  3  3
# 4           4  2  0  0  4  1
# 5           5  2  2  4  2  3
# 6           6  2  4  0  3  1
# 7           7  1  3  2  4  1
# 8           8  1  0  4  4  0
# 9           9  4  2  0  1  2

# %% [markdown]
# ### Parquet

# %%
df.to_parquet("foo.parquet")

# %%
pd.read_parquet("foo.parquet")
# Out:
#    0  1  2  3  4
# 0  1  1  0  2  4
# 1  3  3  0  1  2
# 2  2  0  3  3  1
# 3  1  3  3  3  3
# 4  2  0  0  4  1
# 5  2  2  4  2  3
# 6  2  4  0  3  1
# 7  1  3  2  4  1
# 8  1  0  4  4  0
# 9  4  2  0  1  2

# %% [markdown]
# ### Excel

# %%
df.to_excel("foo.xlsx", sheet_name="Sheet1")

# %%
pd.read_excel("foo.xlsx", "Sheet1", index_col=None, na_values=["NA"])
# Out:
#    Unnamed: 0  0  1  2  3  4
# 0           0  1  1  0  2  4
# 1           1  3  3  0  1  2
# 2           2  2  0  3  3  1
# 3           3  1  3  3  3  3
# 4           4  2  0  0  4  1
# 5           5  2  2  4  2  3
# 6           6  2  4  0  3  1
# 7           7  1  3  2  4  1
# 8           8  1  0  4  4  0
# 9           9  4  2  0  1  2

# %% [markdown]
# ### Gotchas

# %% [markdown]
# If you are attempting to perform a boolean operation on a Series or DataFrame you might see an exception like:
#
#
#     if pd.Series([False, True, False]):
#          print("I was true")
#
# note: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
